# %%
import matplotlib.pyplot as plt

# Word counts from your results
models = ['Golden Transcript', 'ChatGPT-4.1', 'Moonshot', 'Meta', 'DeepSeek']
word_counts = [6216, 2309, 1817, 1693, 950]  # Replace with your actual counts if different

# Create bar plot
plt.figure(figsize=(8, 5))
bars = plt.bar(models, word_counts, color=['gray', 'skyblue', 'lightgreen', 'orange', 'red'])

# Add value labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 50, int(yval), 
             ha='center', va='bottom', fontsize=10)

# Titles and labels
plt.title('Word Count Comparison: Golden Transcript vs LLM Outputs', fontsize=14)
plt.ylabel('Word Count', fontsize=12)
plt.xlabel('Transcript Source', fontsize=12)
plt.xticks(rotation=20)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Model names and ratings
models = ['ChatGPT-4.1', 'Moonshot', 'Meta', 'DeepSeek']
ratings = [1, 7, 1, 6]  # Ratings from psychologist on a 10-point scale

# Create horizontal bar chart
plt.figure(figsize=(7, 4))
bars = plt.barh(models, ratings, color=['red', 'green', 'red', 'orange'])

# Add value labels next to bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.2, bar.get_y() + bar.get_height()/2,
             f'{width}/10', va='center', fontsize=10)

# Formatting
plt.xlabel('Rating (1–10)')
plt.title('Psychologist Ratings of LLM-Generated Transcripts')
plt.xlim(0, 10)  # Set scale to match rating system
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Word counts from your results
models = ['Golden Transcript', 'ChatGPT-4.1', 'Moonshot', 'Meta', 'DeepSeek']
word_counts = [6216, 2309, 1817, 1693, 950]  # Replace with your actual counts if different

# Create bar plot
plt.figure(figsize=(8, 5))
bars = plt.bar(models, word_counts, color=['gray', 'skyblue', 'lightgreen', 'orange', 'red'])

# Add value labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 50, int(yval), 
             ha='center', va='bottom', fontsize=10)

# Titles and labels
plt.title('Word Count Comparison: Golden Transcript vs LLM Outputs', fontsize=14)
plt.ylabel('Word Count', fontsize=12)
plt.xlabel('Transcript Source', fontsize=12)
plt.xticks(rotation=20)
plt.tight_layout()

# Save the figure as PNG before showing
plt.savefig("word_count_comparison.png", dpi=300, bbox_inches='tight')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['ChatGPT', 'DeepSeek', 'Meta', 'Moonshot']
ratings = [7, 7, 6, 7]  # Average ratings across both methods

# Plot
plt.figure(figsize=(7, 5))
bars = plt.bar(models, ratings, color='lightcoral')

# Labels and formatting
plt.title('Average Ratings Across Both Summarisation Methods')
plt.xlabel('Language Models')
plt.ylabel('Average Rating (0-10)')
plt.ylim(0, 10)

# Annotate bars
for bar in bars:
    height = bar.get_height()
    plt.annotate(f'{height}', xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3), textcoords="offset points",
                 ha='center', va='bottom')

# Save the plot as PNG
plt.tight_layout()
plt.savefig("average_ratings_summarisation.png", dpi=300)  # <-- Save image here

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['ChatGPT', 'DeepSeek', 'Meta', 'Moonshot']
ratings = [7, 7, 6, 7]  # Average ratings across both methods

# Plot
plt.figure(figsize=(7, 4))
bars = plt.barh(models, ratings, color='#8ECFC9')  # Soft pastel blue

# Labels and formatting
plt.title('Average Ratings Across Both Summarisation Methods', fontsize=12)
plt.xlabel('Average Rating (0-10)', fontsize=10)
plt.xlim(0, 10)
plt.gca().invert_yaxis()  # Highest rating at the top for readability

# Annotate bars
for bar in bars:
    width = bar.get_width()
    plt.annotate(f'{width}', xy=(width, bar.get_y() + bar.get_height() / 2),
                 xytext=(5, 0), textcoords="offset points",
                 ha='left', va='center', fontsize=9)

# Save the plot as PNG
plt.tight_layout()
plt.savefig("average_ratings_summarisation_horizontal.png", dpi=300)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Word counts from your results
models = ['Golden Transcript', 'ChatGPT-4.1', 'Moonshot', 'Meta', 'DeepSeek']
word_counts = [6216, 2309, 1817, 1693, 950]  # Replace with actual counts if needed

# Create horizontal bar plot
plt.figure(figsize=(8, 5))
bars = plt.barh(models, word_counts, color=['#B0BEC5', '#8ECFC9', '#F6C177', '#F3D250', '#F28B82'])  # Pastel palette

# Add value labels next to bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 100, bar.get_y() + bar.get_height()/2, int(width),
             ha='left', va='center', fontsize=10)

# Titles and labels
plt.title('Word Count Comparison: Golden Transcript vs LLM Outputs', fontsize=13)
plt.xlabel('Word Count', fontsize=11)
plt.gca().invert_yaxis()  # Highest value at top for readability

# Save the figure as PNG before showing
plt.tight_layout()
plt.savefig("word_count_comparison_horizontal.png", dpi=300, bbox_inches='tight')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Objective 3 qualitative analysis
models = ['ChatGPT', 'DeepSeek', 'Meta', 'Moonshot']
ratings = [6, 7, 3, 4]  # Average ratings for Objective 3 messages

# Plot
plt.figure(figsize=(7, 4))
bars = plt.barh(models, ratings, color='#8ECFC9')  # Soft pastel blue for consistency

# Labels and formatting
plt.title('Average Ratings for Notification Messages (Objective 3)', fontsize=12)
plt.xlabel('Average Rating (0-10)', fontsize=10)
plt.xlim(0, 10)
plt.gca().invert_yaxis()  # Highest rating at the top

# Annotate bars with ratings
for bar in bars:
    width = bar.get_width()
    plt.annotate(f'{width}', xy=(width, bar.get_y() + bar.get_height() / 2),
                 xytext=(5, 0), textcoords="offset points",
                 ha='left', va='center', fontsize=9)

# Save the plot as PNG
plt.tight_layout()
plt.savefig("objective3_ratings_horizontal.png", dpi=300)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Model names and ratings
models = ['ChatGPT-4.1', 'Moonshot', 'Meta', 'DeepSeek']
ratings = [1, 7, 1, 6]  # Ratings from psychologist on a 10-point scale

# Create horizontal bar chart with soft pastel blue color
plt.figure(figsize=(7, 4))
bars = plt.barh(models, ratings, color=['#8ECFC9'] * len(models))  # Soft pastel blue

# Add value labels next to bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.2, bar.get_y() + bar.get_height()/2,
             f'{width}/10', va='center', fontsize=10)

# Formatting
plt.xlabel('Rating (1–10)')
plt.title('Psychologist Ratings of LLM-Generated Transcripts')
plt.xlim(0, 10)  # Set scale to match rating system
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Save plot as PNG
plt.savefig("psychologist_ratings.png", dpi=300, bbox_inches='tight')

# Show plot
plt.show()
